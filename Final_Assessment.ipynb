# %% [markdown]
# Each student will conduct an independent research project of their
# choosing, which will be assessed through a final project report due at the
# end of the semester. You should select a topic that is of interest to you
# and find relevant data, then use the methods from the class (You are
# allowed to research your topic, but you must stick to the methods and
# tools included in the class). You will have to write a report in the form of a
# scientific paper using a Jupyter Notebook (thus training for the writing of
# your dissertation). The Jupyter Notebook should be available in a GitHub
# Repository, ready to be reproduced. More details will be provided in class
# and on Moodle.

# %% [markdown]
# Notes from Lecture on Week 8
# * You can use mixed methods or just pick one of the methods in the labs
#
# 1. Urban Networks and Mapping Flows
# 2. Geodemographics
# 3. Spatial Microsimulation
# Used for health studies
#
# Cities are not always best represented by laters
# - while layering geographics data is helpfil, it is aklso a constraint for some urban applications
# - Themtic mapping may not always be appropriate (subjectivity)
# - can mask real time data in urban envs

# %% [markdown]
# See data science offices for an internship

# %% [markdown]
# # Ideas for the IRP
#
# ## Urban Analytics to distribute financial aid?
# Policy to distribute financial aid
# - hospital, other interventions
# - ABM models - integrates the indiviudals in each household
# - Use alan turning institute data to analyse the impacts of evernts, transport policies, ABM models
# - See alan turning institute in programme projects
#
# ## Identifying Buildings using OSM
# [Identifying buildings](https://www.turing.ac.uk/research/research-projects/colouring-cities-research-programme) - research into the operation andf performance of urbnam areas
# * how many buildings of similar characteristics are there?
# * what is the relationship between building and street characteristics and the wellbeing of communities, or economic properisty?
# * Here's an example in [australia](https://www.colouringaustralia.org/view/age)
#
# ### Causal interferene modelling (what is?)
# [Causal interference modelling](https://turing.ac.uk/research/research-projects/causal-inference-and-agent-based-modelling) - the relationshuip betweennvariables in a population after an intervention. Typically are simulated with an agent based model.
#
# Air Quality Monitoring
#
# See this for digital mobility: https://www.aimsun.com/
#
# ## Traffic agent based modelling
# Traffic:
# * Alternative modes of transport can be modelled with agent based traffic models
# * EU H20202 Momentum: intermediate modelling approach that combined user friendliness with agms
# * [See this paper on carsharing models for Leuven, Belgium](https://link.springer.com/chapter/10.1007/978-981-19-8361-0_4)
# * [The map for the Flemish Strategic traffic models](https://analytics.omnitransnext.dat.nl/public/GX62RrXh2AQrZyTTbizlDey1)
# * Needs a full synthetic population of agents (making trips through the study area)
#
# ## Data from Valencia
# Data from Valencia: [See this paper on carsharing and taxi-fleets](https://link.springer.com/chapter/10.1007/978-3-030-85710-3_23?fromPaywallRec=true)
# * www.valencia.es/val/ajuntament/govern-obert
# * www.ine.es/index.htm
# * https://valencia.opendatasoft.com/pages/home/
#
# ## Simulating Urban Flows for Traffic or Crime: SURF
# [SURF: Simulating Urban Flows](http://surf.leeds.ac.uk/)
# * Can re analyse crime rates becased on estimates of where groups of victims are / moving to, rather than where people live
# * calculating peoples exposure to air polluation based on where they spend their time, rather than where they live - includes exposures during commutes, etc.
# * Some sources: look at census data, survey data, footfall (through wifi and mobile phones?), smart cards, phone signal data, twitter or apps)
# * Census data: flows between home and work for output areas
# * Actiuvity survey for calibration (UK time use survey 2014-2015)
# * UK Time use survey
# * 8000 respondents, demographic and houshold info, main and secondary acitivities, type of location, only 2 days per person
# * Here is the github : https://github.com/nickmalleson/surf
#
# ## Spatial inequalities?
# [Spatial inequality and the smart city](https://www.turing.ac.uk/research/research-projects/spatial-inequality-and-smart-city)
#
# ## Mapping conflict?
# GUARD Project Example Output: Predicting Global Stability at City/Town Scale (Jan 2019)
# * Publication on mapping networks of conflict: [The Spatial Ecology of War and Peace](https://arxiv.org/abs/1604.01693)
#
#
# ## Landuse transportation models: QUANT
# * Simulates location of employment, population, and transport interactions to predict the impact of changes to and on these activites
# * QUANT: [youtube video explaining](https://www.youtube.com/watch?v=lITC4iBQM7U&ab_channel=TheAlanTuringInstitute)
# * census data for where people work and where they live
# * All of the public transport timetables
# * road transport network
# * create the cost function (how long it takes to get from zone a and zone b)
# * lets you create flows by road, bus, rail
# * You can do employment scenairios
# * or a network scenario (change the underlying network then run the shortest paths algorithm)
# * Motorway speed limits: motorway networks and up the speed limit and see what the effect of that is
# * [A new framework for very large-scale urban modelling](https://journals.sagepub.com/doi/10.1177/0042098020982252), a paper
#
# ### [Transportation and Crime in DC](https://crimesciencejournal.biomedcentral.com/articles/10.1186/s40163-015-0026-5)
# Would it be possible to simulate the flows of people through the rail system in DC (by collecting place of residence and place of work) and then analysing the different impacts on crime with different interventions?
#
# Alternatively: measuring the crime-generalising and the crime attracting characteristics of Metro stations
# * Connectedness: which measures the connectedness of each station to the rest of the transit system, thought to serve as a crime generating charactersitics because of the denseness of pptential targets and offenderes (metro system has data on this)
# * Remoteness: remoteness of the station from the center of the transit system --> remote stations provide better opportunities for certain crimes and overall experience higher rates of crimes (e.g., vandalism, disorderly conduct).
# * Accessibility and Activity: measures ease of access and potential lvel of activity around the stations
# * means measuring the number of entertainment and recreation, health, legal, and educational services in the block group that the station was housed (from national establishment time series database). Also included walkability, which was from walkscore.com which measures the walkability of address based on the distance to nearby places and pedestrian frieneldiness from 0 to 100.
# * Also includes ridership: aquired from washington metropolitatan area transit authority
#
# * SES: SES level in the immediate geography of the stations (percentage white, percentage with bachelors, home ownership, employment rate, and household income (American community survey)
#
# Which types of crime: robbery, larceny, aggravated assault, and disorderly conduct
# Times of crime: Peak hours (4:30 am to 9am, and 3pm to 7pm), non peak day hours are 9am to 3pm, and non peak night hours are 7pm to 4:30 am).
#
#
# From SURF:
# Crime. The research will re-analyse crime rates based on estimates of where groups of potential victims are, rather than simply where people live. This will then show us where crime is higher or lower than expected, given the number of people who are in the area at the time and might be victimised. This will have obvious impacts for crime reduction policies and the project will work with the police and crime-reduction experts to make the best use of the results.
#
#
# Ideas to extend this: use osmnx to create buffers
#
# #### Methods:
# 1. Kmeans clustering and geodemographics
# 2. Univariate and Bivariate analysis
# 3. Buffer creation
# 4. Using lonboard, datashader,hvplot for visualisations
# 5. Spatial microsimulation
# 6. Networks
# 7. OSMNX - to extract building footprints (or other urban elements), find travel times, road networks, calculating betweenness, degree centralities
# 8. Creating choropleths uses ploty
#
#
# ### General Resources
# oberly(?) - creating papers in the cloud
# citations: include them

# %% [markdown]
# ## Define the problem:
# - Research question
# - context
# ## Find the data
# - Filter, normalise, reduce
# - re-project
# -transform dtypes
# - use descriptive stats
# ## method
# - define the data manipulation technique
# - draft the process
# - identify limitations
# ## coding
# - structure the method
# - write the code
# - comment them
# - look for efficiency
# ## Conclusions
# - Reflect on the fidnings
# - limitations
# - addressed RQ?

# %% [markdown]
# Data sources:
#
# [Daily Metro Ridership by Station](https://www.wmata.com/initiatives/ridership-portal/Metrorail-Ridership-Summary.cfm)
#
# Street Data and Walking Times from Stations: osmnx
#
# Problem: Most data on crime density is based on estimates of where people live, rather than where people are. This project aims to assess the density of crime in and around transportation hubs, specifically the Metrorail system in Washington D.C. It will also analyse the role of station remoteness and connectedness, the socio-economic status of the surrounding neighborhood, and the number of riders on crime. This in turn can help direct policy by providing areas with the highest number of risk and developing a model for testing different kinds of interventions on ridership.
#
# Research Questions:
# 1. What is the nature of the relationship between metro stations and crime?
# 2. How do socio-economic factors, the accessibility of stations, and the time of day affect crime densities in and around Metro Stations?
# 3. Using an agent-based model of urban flows in D.C., where are the areas of highest crime risk?
#
# Data sources:
# American Community Survey: Socio-economic data for census blocks, employment place of work and place of residence, transportation use
# Open Data DC: Metro Station Locations, Crime Data
# Ridership by Station: Washington Metropolitan Area Transit Authority
# OSMNX: Finding travel times and walking distances from stations
#
#
# Methods:
# 1. Univariate and Bivariate Analysis
# 2. Buffer Creation
# 3. Agent Based Modeling / Spatial Microsimulation
